# %% [markdown]
# <a href="https://colab.research.google.com/github/ENRIQUESPECTER/Mineria-de-Datos/blob/main/funciones_avanzadas_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("part1_employees.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      20 non-null     int64
#  1   name        20 non-null     object
#  2   city        20 non-null     object
#  3   dept        20 non-null     object
#  4   level       20 non-null     object
#  5   hire_date   20 non-null     object
#  6   salary_mxn  20 non-null     int64
#  7   perf_score  20 non-null     float64
#  8   projects    20 non-null     int64
#  9   warnings    20 non-null     int64
#  10  absences    20 non-null     int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 1.8+ KB

# %%
df.head()
# Out:
#    emp_id   name  city   dept   level   hire_date  salary_mxn  perf_score  \
# 0     101    Ana  CDMX  Sales  Senior  2025-11-15       48000        0.90
# 1     102   Luis   GDL  Sales  Junior  2026-01-10       22000        0.82
# 2     103  Marta   MTY    Ops     Mid  2024-06-01       32000        0.75
# 3     104  Jorge  CDMX    Ops  Senior  2023-03-20       51000        0.88
# 4     105  Sofia   QRO     HR     Mid  2022-09-05       30000        0.93
#
#    projects  warnings  absences
# 0        12         1         2
# 1         5         0         0
# 2         8         1         1
# 3        10         0         0
# 4         6         0         0

# %%
df.describe()
# Out:
#           emp_id    salary_mxn  perf_score   projects   warnings   absences
# count   20.00000     20.000000   20.000000  20.000000  20.000000  20.000000
# mean   110.50000  43200.000000    0.814500   9.350000   0.700000   0.500000
# std      5.91608  19011.353948    0.093779   3.498496   0.864505   0.688247
# min    101.00000  21000.000000    0.600000   4.000000   0.000000   0.000000
# 25%    105.75000  30750.000000    0.747500   6.750000   0.000000   0.000000
# 50%    110.50000  38000.000000    0.825000   9.000000   0.500000   0.000000
# 75%    115.25000  51250.000000    0.892500  12.000000   1.000000   1.000000
# max    120.00000  90000.000000    0.950000  16.000000   3.000000   2.000000

# %% [markdown]
# **Obtén todas las filas del depto "Eng" que además tengan perf_score >= 0.85, pero muestra solo las columnas: emp_id, name, city, perf_score, salary_mxn.**

# %%
x = (df["dept"] == "Eng") & (df["perf_score"]>=0.85)
df.loc[x,["emp_id","name","city","perf_score","salary_mxn"]]
# Out:
#     emp_id   name  city  perf_score  salary_mxn
# 6      107  Karla   MTY        0.95       40000
# 11     112  Ramon  CDMX        0.92       90000

# %% [markdown]
# **Del DataFrame completo, obtén las filas 3 a 8 (incluyendo 3 y excluyendo 8), y solo las columnas 0, 1, 5 y 6 (por posición).**

# %%
df.iloc[3:8,[0,1,5,6]]
# Out:
#    emp_id   name   hire_date  salary_mxn
# 3     104  Jorge  2023-03-20       51000
# 4     105  Sofia  2022-09-05       30000
# 5     106  Diego  2021-02-14       78000
# 6     107  Karla  2025-07-01       40000
# 7     108  Pedro  2020-10-30       35000

# %% [markdown]
# **Calcula:Filtra empleados que estén en city CDMX o GDL, con warnings == 0 y absences <= 1. Muestra emp_id, name, city, warnings, absences.**

# %%
cities = ["CDMX","GDL"]
df.query("city in @cities and warnings == 0 and absences<=1")[["emp_id","name","city","perf_score","salary_mxn"]]
# Out:
#     emp_id      name  city  perf_score  salary_mxn
# 1      102      Luis   GDL        0.82       22000
# 3      104     Jorge  CDMX        0.88       51000
# 11     112     Ramon  CDMX        0.92       90000
# 16     117  Fernanda  CDMX        0.91       24000

# %% [markdown]
# **Calcula:
# salario promedio (salary_mxn)
# perf promedio (perf_score)
# total de warnings (warnings)
# en una sola salida (por ejemplo usando agg).**

# %%
df.agg (
    salario_promedio = ("salary_mxn","mean"),
    perf_promedio = ("perf_score","mean"),
    total_warnings = ("warnings","sum")
)
# Out:
#                   salary_mxn  perf_score  warnings
# salario_promedio     43200.0         NaN       NaN
# perf_promedio            NaN      0.8145       NaN
# total_warnings           NaN         NaN      14.0

# %% [markdown]
# **Por cada dept, calcula:
# número de empleados
# salario promedio
# perf promedio
# Ordena el resultado por salario promedio descendente.**

# %%
resp5 = (
    df.groupby("dept")
    .agg(
        empleados = ("dept","count"),
        salario_promedio = ("salary_mxn","mean"),
        perf_promedio = ("perf_score","mean")
    )
    .sort_values("salario_promedio",ascending=False)
)

resp5
# Out:
#        empleados  salario_promedio  perf_promedio
# dept
# Eng            6      62833.333333          0.835
# Sales          6      35833.333333          0.780
# Ops            5      34400.000000          0.780
# HR             3      33333.333333          0.900
